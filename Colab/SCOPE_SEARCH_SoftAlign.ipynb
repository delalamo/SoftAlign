# %% [markdown]
# <a href="https://colab.research.google.com/github/jtrinquier/SoftAlign/blob/main/SCOPE_SEARCH_SoftAlign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jax
!  pip install git+https://github.com/deepmind/dm-haiku
import haiku as hk
import jax.numpy as jnp
from jax import vmap
import numpy as np
import time
import numpy as np
import time
import ENCODING as enco
import Score_align as score_
import utils
# Out:
# Collecting git+https://github.com/deepmind/dm-haiku
#   Cloning https://github.com/deepmind/dm-haiku to /tmp/pip-req-build-8rhjjv08
#   Running command git clone --filter=blob:none --quiet https://github.com/deepmind/dm-haiku /tmp/pip-req-build-8rhjjv08
#   Resolved https://github.com/deepmind/dm-haiku to commit d14f1b62798a4da47cf3243cd87b1ad7dc52a108
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from dm-haiku==0.0.14.dev0) (1.4.0)
# Collecting jmp>=0.0.2 (from dm-haiku==0.0.14.dev0)
#   Downloading jmp-0.0.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from dm-haiku==0.0.14.dev0) (2.0.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from dm-haiku==0.0.14.dev0) (0.9.0)
# Downloading jmp-0.0.4-py3-none-any.whl (18 kB)
# Building wheels for collected packages: dm-haiku
#   Building wheel for dm-haiku (setup.py) ... done
#   Created wheel for dm-haiku: filename=dm_haiku-0.0.14.dev0-py3-none-any.whl size=373712 sha256=aad982ec94730ded3e58ababe3ac35293e3272c784acf6a30bbc17e188312a5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-av0xxrk4/wheels/86/29/0a/454c478e7217c383ee3d05aa43cbeff48284c23430f59d0c4f
# Successfully built dm-haiku
# Installing collected packages: jmp, dm-haiku
# Successfully installed dm-haiku-0.0.14.dev0 jmp-0.0.4

# %% [markdown]
# If you want to work on SCOPE, run the first cell, if you have your custom pdb folder, run the second

# %%
 # @title SCOPE database Download here https://drive.google.com/file/d/1DFWcUgPukTxWGPUxaeTM1kNEVNCkRgbO/view?usp=sharing
# inputs of ProteinMPNN
import pickle
with open("dicti_inputs_SCOPE_colab",'rb') as fff:

  dicti_inputs = pickle.load(fff)

# %%
 # @title Custom pdbs folder
pdb_folder_path = "pdb_folder" # @param {"type":"string"}


import Input_MPNN as inp
import os

def process_pdb_folder(pdb_folder, chain='A'):
    data = {}
    for filename in os.listdir(pdb_folder):
        if filename.endswith(".pdb"):
            pdb_path = os.path.join(pdb_folder, filename)
            coords, mask, chain_, res = inp.get_inputs_mpnn(pdb_path, chain=chain)
            data[filename] = (
                coords,
                mask,
                chain_,
                res
            )
            print(f"Processed {filename}")
    return data

dicti_inputs = process_pdb_folder(pdb_folder_path)
#print(dicti_inputs)
# Out:
# Processed 3f08.pdb
# Processed 3ejv.pdb
# Processed 3erw.pdb
# Processed 3jtd.pdb
# Processed 3f04.pdb
# Processed 3edh.pdb
# Processed 3jqw.pdb
# Processed 3do6.pdb
# Processed 3e9n.pdb
# Processed 3jtg.pdb

# %%
# MODEL

params_path = "./CONT_SFT_06_T_3_1" #@param {type:"string"}

params= pickle.load(open(params_path,"rb"))
# Out:
# <ipython-input-2-87e59704d7e1>:5: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   params= pickle.load(open(params_path,"rb"))

# %% [markdown]
# # ENCODING

# %%
key = jax.random.PRNGKey(0)

num_layers = 3 #@param {type:"integer"}
num_neighbors = 64 #@param {type:"integer"}
encoding_dim = 64 #@param {type:"integer"}
categorical = False #@param {type:"boolean"}
nb_clusters = 20 #@param {type:"integer"}


def enco_(x1,node_features = encoding_dim,
                 edge_features = encoding_dim, hidden_dim = encoding_dim,
                 num_encoder_layers=num_layers,
                  k_neighbors=num_neighbors,categorical = categorical,nb_clusters = nb_clusters):
  if categorical:
      a = enco.ENCODING_KMEANS_SEQ(node_features,edge_features,hidden_dim,num_encoder_layers,k_neighbors,nb_clusters = nb_clusters)

  else:

    a = enco.ENCODING(node_features,edge_features,hidden_dim,num_encoder_layers,k_neighbors)
  return a(x1)

ENCO = hk.transform(enco_)
@jax.jit
def enco_fast(params,key,input_data):
  return ENCO.apply(params,key,input_data)

# %%
# @title Prepare data

X1s = []
mask1s = []
chain1s = []
res1s = []

id1s = []
l1 = []

for k in dicti_inputs.keys():
    pr1 = k
    _X1, _mask1, _chain1, _res1 = dicti_inputs[pr1]
    id1s.append(pr1)
    X1s.append(_X1[0])
    mask1s.append(_mask1[0])
    chain1s.append(_chain1[0])
    res1s.append(_res1[0])
    l1.append(len(_X1[0]))

max_len = max(l1)

# NOTE: If max_size is too large, consider splitting your data into smaller chunks

print(f"max_size set to: {max_len}")
# Out:
# max_size set to: 1419

# %%
# @title Create encodings
ENCOO = hk.transform(enco_)
encodings = []
# Set batch size
bs = 10
num_samples = len(X1s)

# Convert lists to numpy arrays
X1s = np.array(X1s,dtype=object)
mask1s = np.array(mask1s,dtype=object)
res1s = np.array(res1s,dtype=object)
chain1s = np.array(chain1s,dtype=object)

key = jax.random.PRNGKey(42)

# Start timer
beg = time.time()

# Loop over batches
for i in range(num_samples // bs):
    # Pad the current batch
    X1, mask1, res1, chain1, X2, mask2, res2, chain2, lens = utils.pad_(
        X1s[i * bs:(i + 1) * bs], mask1s[i * bs:(i + 1) * bs], res1s[i * bs:(i + 1) * bs], chain1s[i * bs:(i + 1) * bs],
        X1s[i * bs:(i + 1) * bs], mask1s[i * bs:(i + 1) * bs], res1s[i * bs:(i + 1) * bs], chain1s[i * bs:(i + 1) * bs],
        max_len
    )
    input_data = X2, mask2, res2, chain2
    encodings_ = enco_fast(params, key, input_data)

    # Directly extend the encodings list with the results
    encodings.extend(encodings_)

# Process the remaining samples if any
if num_samples % bs != 0:
    X1, mask1, res1, chain1, X2, mask2, res2, chain2, lens = utils.pad_(
        X1s[num_samples - num_samples % bs:], mask1s[num_samples - num_samples % bs:], res1s[num_samples - num_samples % bs:],
        chain1s[num_samples - num_samples % bs:], X1s[num_samples - num_samples % bs:], mask1s[num_samples - num_samples % bs:],
        res1s[num_samples - num_samples % bs:], chain1s[num_samples - num_samples % bs:], max_len
    )
    input_data = X2, mask2, res2, chain2
    encodings_ = ENCOO.apply(params, key, input_data)
    encodings.extend(encodings_)

# End timing and print
print(time.time() - beg)



dicti_encodings = {}
for l,k in enumerate(encodings):

  dicti_encodings[id1s[l]] = k[:l1[l],:]
# Out:
# 201.38864922523499

# %% [markdown]
# # Search

# %%
import os

def write_sorted_results(input_file_path, output_dir):
    """
    Reads a results file, groups by the first column, sorts by the last column,
    and writes individual sorted files to the output directory.

    Args:
        input_file_path (str): Path to the input results file.
        output_dir (str): Directory to save the sorted files.
    """
    os.makedirs(output_dir, exist_ok=True)

    # Read lines from the input file
    with open(input_file_path, 'r') as file:
        lines = [line.strip() for line in file]

    # Group lines by the first column
    lines_by_value = {}
    for line in lines:
        values = line.split(',')
        key = values[0]
        if key not in lines_by_value:
            lines_by_value[key] = []
        lines_by_value[key].append(line)

    # Process and write each group to separate files
    for key, lines_for_value in lines_by_value.items():
        sorted_lines = sorted(lines_for_value, key=lambda line: -float(line.split(',')[-1]))
        output_file_path = os.path.join(output_dir, f'{key}.txt')
        with open(output_file_path, 'w') as output_file:
            output_file.writelines(line + '\n' for line in sorted_lines)
        #print(f'Sorted lines for {key} have been written to {output_file_path}')

    print(f'All {len(lines_by_value)} files generated successfully.')

# %%
! mkdir ./search

# %%
import numpy as np
import jax.numpy as jnp
import time
import os

def filter_lists(X1, lengths, encodings, thresh_query, thresh_target, ids):
    min_q, max_q = thresh_query
    min_t, max_t = thresh_target
    X1_q, X1_t, enc_q, enc_t, ids_q, ids_t, len_q, len_t = [], [], [], [], [], [], [], []

    for i in range(len(X1)):
        if min_q < lengths[i] <= max_q:
            X1_q.append(X1[i])
            enc_q.append(encodings[i])
            ids_q.append(ids[i])
            len_q.append([lengths[i]])
        if min_t < lengths[i] <= max_t:
            X1_t.append(X1[i])
            enc_t.append(encodings[i])
            ids_t.append(ids[i])
            len_t.append([lengths[i]])

    print(f" - Selected {len(X1_q)} queries (range: {min_q}-{max_q}) and {len(X1_t)} targets (range: {min_t}-{max_t})")
    return X1_q, X1_t, enc_q, enc_t, len_q, len_t, ids_q, ids_t


def prepare_data(thresh_query=(0, 100), thresh_target=(0, 100)):
    X1, lengths, encodings, ids = [], [], [], []
    for k in dicti_inputs.keys():
        coords = dicti_inputs[k][0][0]
        X1.append(coords)
        lengths.append(coords.shape[0])
        encodings.append(dicti_encodings[k])
        ids.append(k)
    return filter_lists(X1, lengths, encodings, thresh_query, thresh_target, ids)


def pad_data(X_q, X_t, enc_q, enc_t, max_len_q, max_len_t):
    X1_padded = np.array([np.pad(X, ((0, max_len_q - X.shape[0]), (0, 0), (0, 0)), 'constant') for X in X_q])
    X2_padded = np.array([np.pad(X, ((0, max_len_t - X.shape[0]), (0, 0), (0, 0)), 'constant') for X in X_t])
    enc1_padded = jnp.array([jnp.pad(X, ((0, max_len_q - X.shape[0]), (0, 0)), 'constant') for X in enc_q])
    enc2_padded = jnp.array([jnp.pad(X, ((0, max_len_t - X.shape[0]), (0, 0)), 'constant') for X in enc_t])
    return X1_padded, X2_padded, enc1_padded, enc2_padded


def find_divisors(n):
    return [i for i in range(1, n + 1) if n % i == 0]


def batch_generator(X1, X2, enc1, enc2, len1, len2, batch_size):
    n1, n2 = len(enc1), len(enc2)
    X2_aug = jnp.vstack((X2, X2))
    enc2_aug = jnp.vstack((enc2, enc2))
    len2_aug = len2 * 2

    for i in range(0, n1, batch_size):
        batch_X1 = X1[i:i + batch_size]
        batch_enc1 = enc1[i:i + batch_size]
        batch_len1 = len1[i:i + batch_size]

        for j in range(0, n2, 1):
            batch_X2 = X2_aug[j:j + batch_size]
            batch_enc2 = enc2_aug[j:j + batch_size]
            batch_len2 = len2_aug[j:j + batch_size]
            yield batch_X1, batch_X2, batch_enc1, batch_len1, batch_enc2, batch_len2


def generate_pairs(ids1, ids2, batch_size):
    ids2_aug = ids2 * 2
    return [(ids1[i + l], ids2_aug[j + l]) for i in range(0, len(ids1), batch_size) for j in range(0, len(ids2)) for l in range(batch_size)]

# %%
def find_divisors(n):
    """Returns a list of divisors of n."""
    return [i for i in range(1, n + 1) if n % i == 0]

def smart_bin_creator(lengths, min_samples_per_bin=300, max_bin_width=5000):
    """
    Dynamically creates non-overlapping bins based on sequence length distribution.
    Ensures the number of elements inside each bin has a divisor >10 and is even.
    """
    sorted_lengths = sorted(lengths)
    bins = []
    i = 0

    while i < len(sorted_lengths):
        start = sorted_lengths[i] - 1 if i == 0 else sorted_lengths[i]  # ✅ First bin starts at -1
        count = 0
        j = i

        # Expand the bin until reaching min_samples_per_bin or max_bin_width
        while j < len(sorted_lengths) and (sorted_lengths[j] - start) <= max_bin_width:
            count += 1
            if count >= min_samples_per_bin:
                break
            j += 1

        end = sorted_lengths[min(j, len(sorted_lengths) - 1)]  # Default bin end
        num_elements = j - i  # ✅ Number of elements inside the bin

        # Ensure the number of elements meets both conditions
        while True:
            divisors = find_divisors(num_elements)

            if any(d > 10 for d in divisors) and num_elements % 16== 0:  # ✅ Check divisor >10 and even
                break  # ✅ Valid bin found

            # Expand bin if needed (avoid exceeding last length)
            if j < len(sorted_lengths) - 1:
                j += 1
                end = sorted_lengths[min(j, len(sorted_lengths) - 1)]
                num_elements = j - i  # Recalculate elements
            else:
                break  # Stop expanding if at last element

        # Ensure last bin includes the maximum length
        if j >= len(sorted_lengths) - 1:
            end = sorted_lengths[-1] + 1

        bins.append((start, end))
        i = j  # ✅ Move to the next bin without overlap

    return bins

# Example usage
all_lengths = [dicti_inputs[k][0][0, :, :, :].shape[0] for k in dicti_inputs]
print(f"Found {len(all_lengths)} total sequences.")
length_bins = smart_bin_creator(all_lengths, min_samples_per_bin=300, max_bin_width=1000)
print(f"Smart bins: {length_bins}")
# Out:
# Found 11211 total sequences.
# Smart bins: [(4, 41), (41, 55), (55, 63), (63, 70), (70, 76), (76, 82), (82, 87), (87, 92), (92, 96), (96, 101), (101, 105), (105, 110), (110, 115), (115, 120), (120, 124), (124, 129), (129, 134), (134, 140), (140, 146), (146, 153), (153, 160), (160, 167), (167, 176), (176, 184), (184, 194), (194, 206), (206, 217), (217, 230), (230, 244), (244, 258), (258, 273), (273, 292), (292, 314), (314, 343), (343, 380), (380, 452), (452, 1420)]

# %%
min(all_lengths)
# Out:
# 5

# %%
! rm ./search/*

# %%
def smart_bin_pairs(length_bins):
    """
    Pair query bins with target bins aiming for larger batch sizes.
    Returns a list of (query_range, target_range) pairs.
    """
    bin_pairs = []
    for query_bin in length_bins:
        for target_bin in length_bins:
            bin_pairs.append((query_bin, target_bin))
    return bin_pairs

def main_search_smart(length_bins, gap=0.0, open_=0.0, min_batch_size=8):
    print(f"Running SMART search | gap: {gap} | open: {open_}")

    total_start = time.time()

    bin_pairs = smart_bin_pairs(length_bins)

    last_query_bin = None  # Track last query bin

    for query_range, target_range in bin_pairs:
        if query_range != last_query_bin:
            # 🚨 New query bin detected! Reset results and write sorted results for previous bin
            if last_query_bin is not None:
                write_sorted_results("results_search", "search/")  # Sort & save results before switching bins

            print(f"\n🆕 Starting new Query Bin: {query_range}")
            if os.path.exists("results_search"):
                os.remove("results_search")  # Delete results file when changing query bin

            last_query_bin = query_range  # Update last query bin

        print(f"\n🟢 Query Bin: {query_range} x 🔵 Target Bin: {target_range}")
        start = time.time()

        X1f, X2f, enc1f, enc2f, len1f, len2f, ids1, ids2 = prepare_data(query_range, target_range)
        if not X1f or not X2f:
            print(" ⚠️  Skipping (no data found)\n")
            continue

        max_len_q = query_range[1]
        max_len_t = target_range[1]
        X1p, X2p, enc1p, enc2p = pad_data(X1f, X2f, enc1f, enc2f, max_len_q, max_len_t)

        possible_batches = find_divisors(len(X1f))
        cond = (query_range[1] < 500 and target_range[1] < 500)

        if not cond:
            batch_size = max([b for b in possible_batches if b < 10], default=1)
        else:
            batch_size = max([b for b in possible_batches if b <= min(len(X2f), 1000) and b >= min_batch_size], default=1)

        print(f"   ➡️  Total query x target pairs: {len(X1f) * len(X2f)}, Batch size: {batch_size}")
        if batch_size < min_batch_size:
            print(" ⚠️  Not optimal size.\n")
            # continue

        res_lddt = []
        batches = batch_generator(X1p, X2p, enc1p, enc2p, len1f, len2f, batch_size)

        for idx, batch in enumerate(batches):
            batch_X1, batch_X2, batch_enc1, batch_len1, batch_enc2, batch_len2 = batch
            aln = score_.align_argmax(batch_enc1, batch_enc2, jnp.column_stack((batch_len1, batch_len2)), 1e-7)
            col_mask = np.arange(aln.shape[1])[np.newaxis, :] >= np.array(batch_len1)
            mask1 = ~col_mask[:, np.newaxis, :] * ~col_mask[:, :, np.newaxis]
            col_mask2 = np.arange(aln.shape[2])[np.newaxis, :] >= np.array(batch_len2)
            mask2 = ~col_mask2[:, np.newaxis, :] * ~col_mask2[:, :, np.newaxis]

            res_lddt.append(score_.get_LDDTloss(batch_X1[:, :, 1], batch_X2[:, :, 1], aln, mask1, mask2, 10**-4, values_ANG=[0.5, 1, 2, 4]))
            if idx % 500 == 0:
                print(f"     - Processed {idx * batch_size} pairs...")

        res_lddt_array = np.concatenate(res_lddt)
        pairs = generate_pairs(ids1, ids2, batch_size)

        with open("results_search", "a") as f:  # ✅ Append instead of overwrite
            for i in range(len(pairs)):
                f.write(f"{pairs[i][0]},{pairs[i][1]},{res_lddt_array[i]}\n")

        print(f" ✅ Bin {query_range} x {target_range} completed in {time.time() - start:.2f}s\n")

    # ✅ Final sort after last query bin
    write_sorted_results("results_search", "search/")

    print(f"🎉 All SMART searches completed in {time.time() - total_start:.2f}s!")


# --------- USER CONFIG ---------
max_len = max([dicti_inputs[k][0][0, :, :, :].shape[0] for k in dicti_inputs])
print(f"Detected max_len: {max_len}")

main_search_smart(length_bins)
# Out:
# Detected max_len: 1419
# Running SMART search | gap: 0.0 | open: 0.0
#
# 🆕 Starting new Query Bin: (4, 41)
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (4, 41)
#  - Selected 310 queries (range: 4-41) and 310 targets (range: 4-41)
#    ➡️  Total query x target pairs: 96100, Batch size: 310
#      - Processed 0 pairs...
# <ipython-input-55-68740d619ae3>:63: DeprecationWarning: column_stack requires ndarray or scalar arguments, got <class 'list'> at position 0. In a future JAX release this will be an error.
#   aln = score_.align_argmax(batch_enc1, batch_enc2, jnp.column_stack((batch_len1, batch_len2)), 1e-7)
#  ✅ Bin (4, 41) x (4, 41) completed in 2.08s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (41, 55)
#  - Selected 310 queries (range: 4-41) and 322 targets (range: 41-55)
#    ➡️  Total query x target pairs: 99820, Batch size: 310
# (55,) (41,)
# (41, 55) (41, 55)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (41, 55) completed in 3.13s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (55, 63)
#  - Selected 310 queries (range: 4-41) and 300 targets (range: 55-63)
#    ➡️  Total query x target pairs: 93000, Batch size: 155
# (63,) (41,)
# (41, 63) (41, 63)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (55, 63) completed in 4.01s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (63, 70)
#  - Selected 310 queries (range: 4-41) and 290 targets (range: 63-70)
#    ➡️  Total query x target pairs: 89900, Batch size: 155
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (63, 70) completed in 2.86s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (70, 76)
#  - Selected 310 queries (range: 4-41) and 301 targets (range: 70-76)
#    ➡️  Total query x target pairs: 93310, Batch size: 155
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (70, 76) completed in 3.00s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (76, 82)
#  - Selected 310 queries (range: 4-41) and 339 targets (range: 76-82)
#    ➡️  Total query x target pairs: 105090, Batch size: 310
# (82,) (41,)
# (41, 82) (41, 82)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (76, 82) completed in 3.28s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (82, 87)
#  - Selected 310 queries (range: 4-41) and 306 targets (range: 82-87)
#    ➡️  Total query x target pairs: 94860, Batch size: 155
# (87,) (41,)
# (41, 87) (41, 87)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (82, 87) completed in 4.16s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (87, 92)
#  - Selected 310 queries (range: 4-41) and 308 targets (range: 87-92)
#    ➡️  Total query x target pairs: 95480, Batch size: 155
# (92,) (41,)
# (41, 92) (41, 92)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (87, 92) completed in 4.30s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (92, 96)
#  - Selected 310 queries (range: 4-41) and 266 targets (range: 92-96)
#    ➡️  Total query x target pairs: 82460, Batch size: 155
# (96,) (41,)
# (41, 96) (41, 96)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (92, 96) completed in 3.83s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (96, 101)
#  - Selected 310 queries (range: 4-41) and 336 targets (range: 96-101)
#    ➡️  Total query x target pairs: 104160, Batch size: 310
# (101,) (41,)
# (41, 101) (41, 101)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (96, 101) completed in 3.26s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (101, 105)
#  - Selected 310 queries (range: 4-41) and 290 targets (range: 101-105)
#    ➡️  Total query x target pairs: 89900, Batch size: 155
# (105,) (41,)
# (41, 105) (41, 105)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (101, 105) completed in 4.19s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (105, 110)
#  - Selected 310 queries (range: 4-41) and 309 targets (range: 105-110)
#    ➡️  Total query x target pairs: 95790, Batch size: 155
# (110,) (41,)
# (41, 110) (41, 110)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (105, 110) completed in 3.96s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (110, 115)
#  - Selected 310 queries (range: 4-41) and 320 targets (range: 110-115)
#    ➡️  Total query x target pairs: 99200, Batch size: 310
# (115,) (41,)
# (41, 115) (41, 115)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (110, 115) completed in 3.52s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (115, 120)
#  - Selected 310 queries (range: 4-41) and 297 targets (range: 115-120)
#    ➡️  Total query x target pairs: 92070, Batch size: 155
# (120,) (41,)
# (41, 120) (41, 120)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (115, 120) completed in 4.36s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (120, 124)
#  - Selected 310 queries (range: 4-41) and 272 targets (range: 120-124)
#    ➡️  Total query x target pairs: 84320, Batch size: 155
# (124,) (41,)
# (41, 124) (41, 124)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (120, 124) completed in 3.90s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (124, 129)
#  - Selected 310 queries (range: 4-41) and 299 targets (range: 124-129)
#    ➡️  Total query x target pairs: 92690, Batch size: 155
# (129,) (41,)
# (41, 129) (41, 129)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (124, 129) completed in 4.04s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (129, 134)
#  - Selected 310 queries (range: 4-41) and 328 targets (range: 129-134)
#    ➡️  Total query x target pairs: 101680, Batch size: 310
# (134,) (41,)
# (41, 134) (41, 134)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (129, 134) completed in 4.18s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (134, 140)
#  - Selected 310 queries (range: 4-41) and 299 targets (range: 134-140)
#    ➡️  Total query x target pairs: 92690, Batch size: 155
# (140,) (41,)
# (41, 140) (41, 140)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (134, 140) completed in 4.49s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (140, 146)
#  - Selected 310 queries (range: 4-41) and 290 targets (range: 140-146)
#    ➡️  Total query x target pairs: 89900, Batch size: 155
# (146,) (41,)
# (41, 146) (41, 146)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (140, 146) completed in 4.66s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (146, 153)
#  - Selected 310 queries (range: 4-41) and 342 targets (range: 146-153)
#    ➡️  Total query x target pairs: 106020, Batch size: 310
# (153,) (41,)
# (41, 153) (41, 153)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (146, 153) completed in 4.92s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (153, 160)
#  - Selected 310 queries (range: 4-41) and 298 targets (range: 153-160)
#    ➡️  Total query x target pairs: 92380, Batch size: 155
# (160,) (41,)
# (41, 160) (41, 160)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (153, 160) completed in 5.02s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (160, 167)
#  - Selected 310 queries (range: 4-41) and 278 targets (range: 160-167)
#    ➡️  Total query x target pairs: 86180, Batch size: 155
# (167,) (41,)
# (41, 167) (41, 167)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (160, 167) completed in 4.81s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (167, 176)
#  - Selected 310 queries (range: 4-41) and 316 targets (range: 167-176)
#    ➡️  Total query x target pairs: 97960, Batch size: 310
# (176,) (41,)
# (41, 176) (41, 176)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (167, 176) completed in 4.89s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (176, 184)
#  - Selected 310 queries (range: 4-41) and 284 targets (range: 176-184)
#    ➡️  Total query x target pairs: 88040, Batch size: 155
# (184,) (41,)
# (41, 184) (41, 184)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (176, 184) completed in 5.13s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (184, 194)
#  - Selected 310 queries (range: 4-41) and 301 targets (range: 184-194)
#    ➡️  Total query x target pairs: 93310, Batch size: 155
# (194,) (41,)
# (41, 194) (41, 194)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (184, 194) completed in 5.74s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (194, 206)
#  - Selected 310 queries (range: 4-41) and 325 targets (range: 194-206)
#    ➡️  Total query x target pairs: 100750, Batch size: 310
# (206,) (41,)
# (41, 206) (41, 206)
#      - Processed 0 pairs...
#  ✅ Bin (4, 41) x (194, 206) completed in 5.70s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (206, 217)
#  - Selected 310 queries (range: 4-41) and 292 targets (range: 206-217)
#    ➡️  Total query x target pairs: 90520, Batch size: 155
# (217,) (41,)
# (41, 217) (41, 217)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (206, 217) completed in 5.89s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (217, 230)
#  - Selected 310 queries (range: 4-41) and 300 targets (range: 217-230)
#    ➡️  Total query x target pairs: 93000, Batch size: 155
# (230,) (41,)
# (41, 230) (41, 230)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (217, 230) completed in 6.52s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (230, 244)
#  - Selected 310 queries (range: 4-41) and 306 targets (range: 230-244)
#    ➡️  Total query x target pairs: 94860, Batch size: 155
# (244,) (41,)
# (41, 244) (41, 244)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (230, 244) completed in 6.78s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (244, 258)
#  - Selected 310 queries (range: 4-41) and 297 targets (range: 244-258)
#    ➡️  Total query x target pairs: 92070, Batch size: 155
# (258,) (41,)
# (41, 258) (41, 258)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (244, 258) completed in 7.01s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (258, 273)
#  - Selected 310 queries (range: 4-41) and 308 targets (range: 258-273)
#    ➡️  Total query x target pairs: 95480, Batch size: 155
# (273,) (41,)
# (41, 273) (41, 273)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (258, 273) completed in 7.63s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (273, 292)
#  - Selected 310 queries (range: 4-41) and 305 targets (range: 273-292)
#    ➡️  Total query x target pairs: 94550, Batch size: 155
# (292,) (41,)
# (41, 292) (41, 292)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (273, 292) completed in 8.09s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (292, 314)
#  - Selected 310 queries (range: 4-41) and 301 targets (range: 292-314)
#    ➡️  Total query x target pairs: 93310, Batch size: 155
# (314,) (41,)
# (41, 314) (41, 314)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (292, 314) completed in 8.69s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (314, 343)
#  - Selected 310 queries (range: 4-41) and 309 targets (range: 314-343)
#    ➡️  Total query x target pairs: 95790, Batch size: 155
# (343,) (41,)
# (41, 343) (41, 343)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (314, 343) completed in 9.87s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (343, 380)
#  - Selected 310 queries (range: 4-41) and 301 targets (range: 343-380)
#    ➡️  Total query x target pairs: 93310, Batch size: 155
# (380,) (41,)
# (41, 380) (41, 380)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (343, 380) completed in 11.02s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (380, 452)
#  - Selected 310 queries (range: 4-41) and 302 targets (range: 380-452)
#    ➡️  Total query x target pairs: 93620, Batch size: 155
# (452,) (41,)
# (41, 452) (41, 452)
#      - Processed 0 pairs...
#      - Processed 77500 pairs...
#  ✅ Bin (4, 41) x (380, 452) completed in 15.01s
#
#
# 🟢 Query Bin: (4, 41) x 🔵 Target Bin: (452, 1420)
#  - Selected 310 queries (range: 4-41) and 264 targets (range: 452-1420)
#    ➡️  Total query x target pairs: 81840, Batch size: 5
#  ⚠️  Not optimal size.
#
#      - Processed 0 pairs...
#      - Processed 2500 pairs...
#      - Processed 5000 pairs...
#      - Processed 7500 pairs...
#      - Processed 10000 pairs...
#      - Processed 12500 pairs...
#      - Processed 15000 pairs...
#      - Processed 17500 pairs...
#      - Processed 20000 pairs...
#      - Processed 22500 pairs...
#      - Processed 25000 pairs...
#      - Processed 27500 pairs...
#      - Processed 30000 pairs...
#      - Processed 32500 pairs...
#      - Processed 35000 pairs...
#      - Processed 37500 pairs...
#      - Processed 40000 pairs...
#      - Processed 42500 pairs...
#      - Processed 45000 pairs...
#      - Processed 47500 pairs...
#      - Processed 50000 pairs...
#      - Processed 52500 pairs...
#      - Processed 55000 pairs...
#      - Processed 57500 pairs...
#      - Processed 60000 pairs...
#      - Processed 62500 pairs...
#      - Processed 65000 pairs...
#      - Processed 67500 pairs...
#      - Processed 70000 pairs...
#      - Processed 72500 pairs...
#      - Processed 75000 pairs...
#      - Processed 77500 pairs...
#      - Processed 80000 pairs...
#  ✅ Bin (4, 41) x (452, 1420) completed in 97.50s
#
# All 310 files generated successfully.
#
# 🆕 Starting new Query Bin: (41, 55)
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (4, 41)
#  - Selected 322 queries (range: 41-55) and 310 targets (range: 4-41)
#    ➡️  Total query x target pairs: 99820, Batch size: 161
# (41,) (55,)
# (55, 41) (55, 41)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (4, 41) completed in 4.30s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (41, 55)
#  - Selected 322 queries (range: 41-55) and 322 targets (range: 41-55)
#    ➡️  Total query x target pairs: 103684, Batch size: 322
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (41, 55) completed in 3.01s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (55, 63)
#  - Selected 322 queries (range: 41-55) and 300 targets (range: 55-63)
#    ➡️  Total query x target pairs: 96600, Batch size: 161
# (63,) (55,)
# (55, 63) (55, 63)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (55, 63) completed in 3.79s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (63, 70)
#  - Selected 322 queries (range: 41-55) and 290 targets (range: 63-70)
#    ➡️  Total query x target pairs: 93380, Batch size: 161
# (70,) (55,)
# (55, 70) (55, 70)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (63, 70) completed in 3.81s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (70, 76)
#  - Selected 322 queries (range: 41-55) and 301 targets (range: 70-76)
#    ➡️  Total query x target pairs: 96922, Batch size: 161
# (76,) (55,)
# (55, 76) (55, 76)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (70, 76) completed in 3.97s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (76, 82)
#  - Selected 322 queries (range: 41-55) and 339 targets (range: 76-82)
#    ➡️  Total query x target pairs: 109158, Batch size: 322
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (76, 82) completed in 3.12s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (82, 87)
#  - Selected 322 queries (range: 41-55) and 306 targets (range: 82-87)
#    ➡️  Total query x target pairs: 98532, Batch size: 161
# (87,) (55,)
# (55, 87) (55, 87)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (82, 87) completed in 3.96s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (87, 92)
#  - Selected 322 queries (range: 41-55) and 308 targets (range: 87-92)
#    ➡️  Total query x target pairs: 99176, Batch size: 161
# (92,) (55,)
# (55, 92) (55, 92)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (87, 92) completed in 4.01s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (92, 96)
#  - Selected 322 queries (range: 41-55) and 266 targets (range: 92-96)
#    ➡️  Total query x target pairs: 85652, Batch size: 161
# (96,) (55,)
# (55, 96) (55, 96)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (92, 96) completed in 3.57s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (96, 101)
#  - Selected 322 queries (range: 41-55) and 336 targets (range: 96-101)
#    ➡️  Total query x target pairs: 108192, Batch size: 322
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (96, 101) completed in 3.16s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (101, 105)
#  - Selected 322 queries (range: 41-55) and 290 targets (range: 101-105)
#    ➡️  Total query x target pairs: 93380, Batch size: 161
# (105,) (55,)
# (55, 105) (55, 105)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (101, 105) completed in 4.05s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (105, 110)
#  - Selected 322 queries (range: 41-55) and 309 targets (range: 105-110)
#    ➡️  Total query x target pairs: 99498, Batch size: 161
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (105, 110) completed in 3.82s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (110, 115)
#  - Selected 322 queries (range: 41-55) and 320 targets (range: 110-115)
#    ➡️  Total query x target pairs: 103040, Batch size: 161
# (115,) (55,)
# (55, 115) (55, 115)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (110, 115) completed in 4.25s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (115, 120)
#  - Selected 322 queries (range: 41-55) and 297 targets (range: 115-120)
#    ➡️  Total query x target pairs: 95634, Batch size: 161
# (120,) (55,)
# (55, 120) (55, 120)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (115, 120) completed in 4.12s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (120, 124)
#  - Selected 322 queries (range: 41-55) and 272 targets (range: 120-124)
#    ➡️  Total query x target pairs: 87584, Batch size: 161
# (124,) (55,)
# (55, 124) (55, 124)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (120, 124) completed in 3.90s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (124, 129)
#  - Selected 322 queries (range: 41-55) and 299 targets (range: 124-129)
#    ➡️  Total query x target pairs: 96278, Batch size: 161
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (124, 129) completed in 3.86s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (129, 134)
#  - Selected 322 queries (range: 41-55) and 328 targets (range: 129-134)
#    ➡️  Total query x target pairs: 105616, Batch size: 322
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (129, 134) completed in 3.66s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (134, 140)
#  - Selected 322 queries (range: 41-55) and 299 targets (range: 134-140)
#    ➡️  Total query x target pairs: 96278, Batch size: 161
# (140,) (55,)
# (55, 140) (55, 140)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (134, 140) completed in 4.23s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (140, 146)
#  - Selected 322 queries (range: 41-55) and 290 targets (range: 140-146)
#    ➡️  Total query x target pairs: 93380, Batch size: 161
# (146,) (55,)
# (55, 146) (55, 146)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (140, 146) completed in 4.15s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (146, 153)
#  - Selected 322 queries (range: 41-55) and 342 targets (range: 146-153)
#    ➡️  Total query x target pairs: 110124, Batch size: 322
# (153,) (55,)
# (55, 153) (55, 153)
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (146, 153) completed in 4.23s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (153, 160)
#  - Selected 322 queries (range: 41-55) and 298 targets (range: 153-160)
#    ➡️  Total query x target pairs: 95956, Batch size: 161
# (160,) (55,)
# (55, 160) (55, 160)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (153, 160) completed in 4.34s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (160, 167)
#  - Selected 322 queries (range: 41-55) and 278 targets (range: 160-167)
#    ➡️  Total query x target pairs: 89516, Batch size: 161
# (167,) (55,)
# (55, 167) (55, 167)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (160, 167) completed in 4.35s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (167, 176)
#  - Selected 322 queries (range: 41-55) and 316 targets (range: 167-176)
#    ➡️  Total query x target pairs: 101752, Batch size: 161
# (176,) (55,)
# (55, 176) (55, 176)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (167, 176) completed in 4.73s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (176, 184)
#  - Selected 322 queries (range: 41-55) and 284 targets (range: 176-184)
#    ➡️  Total query x target pairs: 91448, Batch size: 161
# (184,) (55,)
# (55, 184) (55, 184)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (176, 184) completed in 4.64s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (184, 194)
#  - Selected 322 queries (range: 41-55) and 301 targets (range: 184-194)
#    ➡️  Total query x target pairs: 96922, Batch size: 161
# (194,) (55,)
# (55, 194) (55, 194)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (184, 194) completed in 5.13s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (194, 206)
#  - Selected 322 queries (range: 41-55) and 325 targets (range: 194-206)
#    ➡️  Total query x target pairs: 104650, Batch size: 322
# (206,) (55,)
# (55, 206) (55, 206)
#      - Processed 0 pairs...
#  ✅ Bin (41, 55) x (194, 206) completed in 4.79s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (206, 217)
#  - Selected 322 queries (range: 41-55) and 292 targets (range: 206-217)
#    ➡️  Total query x target pairs: 94024, Batch size: 161
# (217,) (55,)
# (55, 217) (55, 217)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (206, 217) completed in 5.11s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (217, 230)
#  - Selected 322 queries (range: 41-55) and 300 targets (range: 217-230)
#    ➡️  Total query x target pairs: 96600, Batch size: 161
# (230,) (55,)
# (55, 230) (55, 230)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (217, 230) completed in 5.42s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (230, 244)
#  - Selected 322 queries (range: 41-55) and 306 targets (range: 230-244)
#    ➡️  Total query x target pairs: 98532, Batch size: 161
# (244,) (55,)
# (55, 244) (55, 244)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (230, 244) completed in 5.92s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (244, 258)
#  - Selected 322 queries (range: 41-55) and 297 targets (range: 244-258)
#    ➡️  Total query x target pairs: 95634, Batch size: 161
# (258,) (55,)
# (55, 258) (55, 258)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (244, 258) completed in 5.99s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (258, 273)
#  - Selected 322 queries (range: 41-55) and 308 targets (range: 258-273)
#    ➡️  Total query x target pairs: 99176, Batch size: 161
# (273,) (55,)
# (55, 273) (55, 273)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (258, 273) completed in 6.52s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (273, 292)
#  - Selected 322 queries (range: 41-55) and 305 targets (range: 273-292)
#    ➡️  Total query x target pairs: 98210, Batch size: 161
# (292,) (55,)
# (55, 292) (55, 292)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (273, 292) completed in 6.80s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (292, 314)
#  - Selected 322 queries (range: 41-55) and 301 targets (range: 292-314)
#    ➡️  Total query x target pairs: 96922, Batch size: 161
# (314,) (55,)
# (55, 314) (55, 314)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (292, 314) completed in 7.30s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (314, 343)
#  - Selected 322 queries (range: 41-55) and 309 targets (range: 314-343)
#    ➡️  Total query x target pairs: 99498, Batch size: 161
# (343,) (55,)
# (55, 343) (55, 343)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (314, 343) completed in 8.19s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (343, 380)
#  - Selected 322 queries (range: 41-55) and 301 targets (range: 343-380)
#    ➡️  Total query x target pairs: 96922, Batch size: 161
# (380,) (55,)
# (55, 380) (55, 380)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (343, 380) completed in 8.99s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (380, 452)
#  - Selected 322 queries (range: 41-55) and 302 targets (range: 380-452)
#    ➡️  Total query x target pairs: 97244, Batch size: 161
# (452,) (55,)
# (55, 452) (55, 452)
#      - Processed 0 pairs...
#      - Processed 80500 pairs...
#  ✅ Bin (41, 55) x (380, 452) completed in 11.20s
#
#
# 🟢 Query Bin: (41, 55) x 🔵 Target Bin: (452, 1420)
#  - Selected 322 queries (range: 41-55) and 264 targets (range: 452-1420)
#    ➡️  Total query x target pairs: 85008, Batch size: 7
#  ⚠️  Not optimal size.
#
# (1420,) (55,)
# (55, 1420) (55, 1420)
#      - Processed 0 pairs...
#      - Processed 3500 pairs...
#      - Processed 7000 pairs...
#      - Processed 10500 pairs...
#      - Processed 14000 pairs...
#      - Processed 17500 pairs...
#      - Processed 21000 pairs...
#      - Processed 24500 pairs...
#      - Processed 28000 pairs...
#      - Processed 31500 pairs...
#      - Processed 35000 pairs...
#      - Processed 38500 pairs...
#      - Processed 42000 pairs...
#      - Processed 45500 pairs...
#      - Processed 49000 pairs...
#      - Processed 52500 pairs...
#      - Processed 56000 pairs...
#      - Processed 59500 pairs...
#      - Processed 63000 pairs...
#      - Processed 66500 pairs...
#      - Processed 70000 pairs...
#      - Processed 73500 pairs...
#      - Processed 77000 pairs...
#      - Processed 80500 pairs...
#      - Processed 84000 pairs...
#  ✅ Bin (41, 55) x (452, 1420) completed in 87.01s
#
# All 322 files generated successfully.
#
# 🆕 Starting new Query Bin: (55, 63)
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (4, 41)
#  - Selected 300 queries (range: 55-63) and 310 targets (range: 4-41)
#    ➡️  Total query x target pairs: 93000, Batch size: 300
# (41,) (63,)
# (63, 41) (63, 41)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (4, 41) completed in 3.23s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (41, 55)
#  - Selected 300 queries (range: 55-63) and 322 targets (range: 41-55)
#    ➡️  Total query x target pairs: 96600, Batch size: 300
# (55,) (63,)
# (63, 55) (63, 55)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (41, 55) completed in 3.01s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (55, 63)
#  - Selected 300 queries (range: 55-63) and 300 targets (range: 55-63)
#    ➡️  Total query x target pairs: 90000, Batch size: 300
# (63,) (63,)
# (63, 63) (63, 63)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (55, 63) completed in 2.86s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (63, 70)
#  - Selected 300 queries (range: 55-63) and 290 targets (range: 63-70)
#    ➡️  Total query x target pairs: 87000, Batch size: 150
# (70,) (63,)
# (63, 70) (63, 70)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (63, 70) completed in 3.95s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (70, 76)
#  - Selected 300 queries (range: 55-63) and 301 targets (range: 70-76)
#    ➡️  Total query x target pairs: 90300, Batch size: 300
# (76,) (63,)
# (63, 76) (63, 76)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (70, 76) completed in 3.05s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (76, 82)
#  - Selected 300 queries (range: 55-63) and 339 targets (range: 76-82)
#    ➡️  Total query x target pairs: 101700, Batch size: 300
# (82,) (63,)
# (63, 82) (63, 82)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (76, 82) completed in 3.27s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (82, 87)
#  - Selected 300 queries (range: 55-63) and 306 targets (range: 82-87)
#    ➡️  Total query x target pairs: 91800, Batch size: 300
# (87,) (63,)
# (63, 87) (63, 87)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (82, 87) completed in 3.07s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (87, 92)
#  - Selected 300 queries (range: 55-63) and 308 targets (range: 87-92)
#    ➡️  Total query x target pairs: 92400, Batch size: 300
# (92,) (63,)
# (63, 92) (63, 92)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (87, 92) completed in 3.18s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (92, 96)
#  - Selected 300 queries (range: 55-63) and 266 targets (range: 92-96)
#    ➡️  Total query x target pairs: 79800, Batch size: 150
# (96,) (63,)
# (63, 96) (63, 96)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (92, 96) completed in 5.73s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (96, 101)
#  - Selected 300 queries (range: 55-63) and 336 targets (range: 96-101)
#    ➡️  Total query x target pairs: 100800, Batch size: 300
# (101,) (63,)
# (63, 101) (63, 101)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (96, 101) completed in 3.36s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (101, 105)
#  - Selected 300 queries (range: 55-63) and 290 targets (range: 101-105)
#    ➡️  Total query x target pairs: 87000, Batch size: 150
# (105,) (63,)
# (63, 105) (63, 105)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (101, 105) completed in 3.90s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (105, 110)
#  - Selected 300 queries (range: 55-63) and 309 targets (range: 105-110)
#    ➡️  Total query x target pairs: 92700, Batch size: 300
# (110,) (63,)
# (63, 110) (63, 110)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (105, 110) completed in 3.24s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (110, 115)
#  - Selected 300 queries (range: 55-63) and 320 targets (range: 110-115)
#    ➡️  Total query x target pairs: 96000, Batch size: 300
# (115,) (63,)
# (63, 115) (63, 115)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (110, 115) completed in 3.34s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (115, 120)
#  - Selected 300 queries (range: 55-63) and 297 targets (range: 115-120)
#    ➡️  Total query x target pairs: 89100, Batch size: 150
# (120,) (63,)
# (63, 120) (63, 120)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (115, 120) completed in 4.05s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (120, 124)
#  - Selected 300 queries (range: 55-63) and 272 targets (range: 120-124)
#    ➡️  Total query x target pairs: 81600, Batch size: 150
# (124,) (63,)
# (63, 124) (63, 124)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (120, 124) completed in 3.84s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (124, 129)
#  - Selected 300 queries (range: 55-63) and 299 targets (range: 124-129)
#    ➡️  Total query x target pairs: 89700, Batch size: 150
# (129,) (63,)
# (63, 129) (63, 129)
#      - Processed 0 pairs...
#      - Processed 75000 pairs...
#  ✅ Bin (55, 63) x (124, 129) completed in 4.02s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (129, 134)
#  - Selected 300 queries (range: 55-63) and 328 targets (range: 129-134)
#    ➡️  Total query x target pairs: 98400, Batch size: 300
# (134,) (63,)
# (63, 134) (63, 134)
#      - Processed 0 pairs...
#  ✅ Bin (55, 63) x (129, 134) completed in 3.76s
#
#
# 🟢 Query Bin: (55, 63) x 🔵 Target Bin: (134, 140)
#  - Selected 300 queries (range: 55-63) and 299 targets (range: 134-140)
#    ➡️  Total query x target pairs: 89700, Batch size: 150
# (140,) (63,)
# (63, 140) (63, 140)
